# %%
 #installing tensorflow version 2.0
 # !pip install tensorflow==2.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0)
# ERROR: No matching distribution found for tensorflow==2.0
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\Ishwarya T\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
#importing all the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Accuracy

from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report,accuracy_score,roc_curve,confusion_matrix

# %%
#styling purpose
# !pip install jupyterthemes
# Out:
# Collecting jupyterthemes
#   Downloading jupyterthemes-0.20.0-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: jupyter-core in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterthemes) (5.7.2)
# Requirement already satisfied: notebook>=5.6.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterthemes) (7.2.1)
# Requirement already satisfied: ipython>=5.4.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterthemes) (8.26.0)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterthemes) (3.9.2)
# Collecting lesscpy>=0.11.2 (from jupyterthemes)
#   Downloading lesscpy-0.15.1-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: decorator in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.14.3)
# Requirement already satisfied: colorama in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.6)
# Collecting ply (from lesscpy>=0.11.2->jupyterthemes)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.9.0.post0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (4.2.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.4.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core->jupyterthemes) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core->jupyterthemes) (306)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (8.6.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (2.0.13)
# Requirement already satisfied: pyzmq>=24 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (73.0.1)
# Requirement already satisfied: babel>=2.10 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (4.22.0)
# Requirement already satisfied: requests>=2.31 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (2.32.3)
# Requirement already satisfied: wcwidth in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.4.1->jupyterthemes) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.3)
# Requirement already satisfied: idna>=2.8 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: certifi in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (1.8.5)
# Requirement already satisfied: nest-asyncio in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (1.6.0)
# Requirement already satisfied: psutil in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.6.0->jupyterthemes) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=5.6.0->jupyterthemes) (2.2.1)
# Requirement already satisfied: webencodings in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (2.4)
# Requirement already satisfied: uri-template in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (2.6)
# Requirement already satisfied: pycparser in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\ishwarya t\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.6.0->jupyterthemes) (2.9.0.20240821)
# Downloading jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB 1.4 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/7.0 MB 5.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/7.0 MB 7.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.9/7.0 MB 5.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/7.0 MB 5.5 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/7.0 MB 5.5 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/7.0 MB 5.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.7/7.0 MB 4.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.9/7.0 MB 4.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.0/7.0 MB 4.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.2/7.0 MB 4.6 MB/s eta 0:00:02
#    ------------- -------------------------- 2.4/7.0 MB 4.5 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.0 MB 4.4 MB/s eta 0:00:01
#    --------------- ------------------------ 2.8/7.0 MB 4.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.9/7.0 MB 4.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.1/7.0 MB 4.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.3/7.0 MB 4.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.5/7.0 MB 4.3 MB/s eta 0:00:01
#    --------------------- ------------------ 3.7/7.0 MB 4.4 MB/s eta 0:00:01
#    --------------------- ------------------ 3.9/7.0 MB 4.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.0/7.0 MB 4.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.2/7.0 MB 4.3 MB/s eta 0:00:01
#    ------------------------- -------------- 4.4/7.0 MB 4.3 MB/s eta 0:00:01
#    -------------------------- ------------- 4.6/7.0 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 4.8/7.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.0/7.0 MB 4.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.1/7.0 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 5.3/7.0 MB 4.2 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/7.0 MB 4.2 MB/s eta 0:00:01
#    -------------------------------- ------- 5.7/7.0 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 5.9/7.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.1/7.0 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.2/7.0 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 6.4/7.0 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 4.1 MB/s eta 0:00:00
# Downloading lesscpy-0.15.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.7 kB ? eta -:--:--
#    ---------------------------------------- 46.7/46.7 kB 2.3 MB/s eta 0:00:00
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.6 kB ? eta -:--:--
#    ---------------------------------------- 49.6/49.6 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: ply, lesscpy, jupyterthemes
# Successfully installed jupyterthemes-0.20.0 lesscpy-0.15.1 ply-3.11
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\Ishwarya T\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
from jupyterthemes import jtplot
jtplot.style(theme = 'monokai', context = 'notebook', ticks = True, grid = False)

# %%
#Load the training and testing datasets
instagram_df_test = pd.read_csv('test.csv')
instagram_df_train = pd.read_csv('train.csv')

# %%
#the dataset which will be used for training purpose (576 records)
instagram_df_train
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
#      name==username  description length  external URL  private  #posts  \
# 0                 0                  53             0        0      32
# 1                 0                  44             0        0     286
# 2                 0                   0             0        1      13
# 3                 0                  82             0        0     679
# 4                 0                   0             0        1       6
# ..              ...                 ...           ...      ...     ...
# 571               0                   0             0        0      33
# 572               0                  21             0        0      44
# 573               0                   0             0        0       4
# 574               0                  11             0        0       0
# 575               0                   0             0        0       2
#
#      #followers  #follows  fake
# 0          1000       955     0
# 1          2740       533     0
# 2           159        98     0
# 3           414       651     0
# 4           151       126     0
# ..          ...       ...   ...
# 571         166       596     1
# 572          66        75     1
# 573          96       339     1
# 574          57        73     1
# 575         150       487     1
#
# [576 rows x 12 columns]

# %%
#the dataset which will be used for testing purpose (120 records)
instagram_df_test
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
#      name==username  description length  external URL  private  #posts  \
# 0                 1                  30             0        1      35
# 1                 0                  64             0        1       3
# 2                 0                  82             0        1     319
# 3                 0                 143             0        1     273
# 4                 0                  76             0        1       6
# ..              ...                 ...           ...      ...     ...
# 115               0                   0             0        0      13
# 116               0                   0             0        0       4
# 117               0                   0             0        0       3
# 118               0                   0             0        0       1
# 119               0                   0             0        0       3
#
#      #followers  #follows  fake
# 0           488       604     0
# 1            35         6     0
# 2           328       668     0
# 3         14890      7369     0
# 4           225       356     0
# ..          ...       ...   ...
# 115         114       811     1
# 116         150       164     1
# 117         833      3572     1
# 118         219      1695     1
# 119          39        68     1
#
# [120 rows x 12 columns]

# %%
#Getting dataframe info

instagram_df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile pic           576 non-null    int64
#  1   nums/length username  576 non-null    float64
#  2   fullname words        576 non-null    int64
#  3   nums/length fullname  576 non-null    float64
#  4   name==username        576 non-null    int64
#  5   description length    576 non-null    int64
#  6   external URL          576 non-null    int64
#  7   private               576 non-null    int64
#  8   #posts                576 non-null    int64
#  9   #followers            576 non-null    int64
#  10  #follows              576 non-null    int64
#  11  fake                  576 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 54.1 KB

# %%
#Statistical summary of the dataframe
instagram_df_train.describe()
# Out:
#        profile pic  nums/length username  fullname words  \
# count   576.000000            576.000000      576.000000
# mean      0.701389              0.163837        1.460069
# std       0.458047              0.214096        1.052601
# min       0.000000              0.000000        0.000000
# 25%       0.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.310000        2.000000
# max       1.000000              0.920000       12.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            576.000000      576.000000          576.000000    576.000000
# mean               0.036094        0.034722           22.623264      0.116319
# std                0.125121        0.183234           37.702987      0.320886
# min                0.000000        0.000000            0.000000      0.000000
# 25%                0.000000        0.000000            0.000000      0.000000
# 50%                0.000000        0.000000            0.000000      0.000000
# 75%                0.000000        0.000000           34.000000      0.000000
# max                1.000000        1.000000          150.000000      1.000000
#
#           private       #posts    #followers     #follows        fake
# count  576.000000   576.000000  5.760000e+02   576.000000  576.000000
# mean     0.381944   107.489583  8.530724e+04   508.381944    0.500000
# std      0.486285   402.034431  9.101485e+05   917.981239    0.500435
# min      0.000000     0.000000  0.000000e+00     0.000000    0.000000
# 25%      0.000000     0.000000  3.900000e+01    57.500000    0.000000
# 50%      0.000000     9.000000  1.505000e+02   229.500000    0.500000
# 75%      1.000000    81.500000  7.160000e+02   589.500000    1.000000
# max      1.000000  7389.000000  1.533854e+07  7500.000000    1.000000

# %%
#Check if null values exist
instagram_df_train.isnull().sum()
# Out:
# profile pic             0
# nums/length username    0
# fullname words          0
# nums/length fullname    0
# name==username          0
# description length      0
# external URL            0
# private                 0
# #posts                  0
# #followers              0
# #follows                0
# fake                    0
# dtype: int64

# %%
#Number of unique values in the profile pic column
instagram_df_train['profile pic'].value_counts()
# Out:
# profile pic
# 1    404
# 0    172
# Name: count, dtype: int64

# %%
#Number of fake and real accounts
instagram_df_train['fake'].value_counts()
# Out:
# fake
# 0    288
# 1    288
# Name: count, dtype: int64

# %%
#Number of accounts having an external URL
instagram_df_train['external URL'].value_counts()
# Out:
# external URL
# 0    509
# 1     67
# Name: count, dtype: int64

# %%
#Number of accounts having description length over 50
(instagram_df_train['description length'] > 50).sum()
# Out:
# np.int64(98)

# %%
instagram_df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile pic           120 non-null    int64
#  1   nums/length username  120 non-null    float64
#  2   fullname words        120 non-null    int64
#  3   nums/length fullname  120 non-null    float64
#  4   name==username        120 non-null    int64
#  5   description length    120 non-null    int64
#  6   external URL          120 non-null    int64
#  7   private               120 non-null    int64
#  8   #posts                120 non-null    int64
#  9   #followers            120 non-null    int64
#  10  #follows              120 non-null    int64
#  11  fake                  120 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 11.4 KB

# %%
instagram_df_test.describe()
# Out:
#        profile pic  nums/length username  fullname words  \
# count   120.000000            120.000000      120.000000
# mean      0.758333              0.179917        1.550000
# std       0.429888              0.241492        1.187116
# min       0.000000              0.000000        0.000000
# 25%       1.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.330000        2.000000
# max       1.000000              0.890000        9.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            120.000000      120.000000          120.000000    120.000000
# mean               0.071333        0.041667           27.200000      0.100000
# std                0.209429        0.200664           42.588632      0.301258
# min                0.000000        0.000000            0.000000      0.000000
# 25%                0.000000        0.000000            0.000000      0.000000
# 50%                0.000000        0.000000            0.000000      0.000000
# 75%                0.000000        0.000000           45.250000      0.000000
# max                1.000000        1.000000          149.000000      1.000000
#
#           private       #posts    #followers     #follows        fake
# count  120.000000   120.000000  1.200000e+02   120.000000  120.000000
# mean     0.308333    82.866667  4.959472e+04   779.266667    0.500000
# std      0.463741   230.468136  3.816126e+05  1409.383558    0.502096
# min      0.000000     0.000000  0.000000e+00     1.000000    0.000000
# 25%      0.000000     1.000000  6.725000e+01   119.250000    0.000000
# 50%      0.000000     8.000000  2.165000e+02   354.500000    0.500000
# 75%      1.000000    58.250000  5.932500e+02   668.250000    1.000000
# max      1.000000  1879.000000  4.021842e+06  7453.000000    1.000000

# %%
instagram_df_test.isnull().sum()
# Out:
# profile pic             0
# nums/length username    0
# fullname words          0
# nums/length fullname    0
# name==username          0
# description length      0
# external URL            0
# private                 0
# #posts                  0
# #followers              0
# #follows                0
# fake                    0
# dtype: int64

# %%
instagram_df_test['fake'].value_counts()
# Out:
# fake
# 0    60
# 1    60
# Name: count, dtype: int64

# %%
#Vislualizing the number of fake and real accounts (using seaborn library)
sns.countplot(instagram_df_train['fake'])
# Out:
# <Axes: ylabel='count'>

# %%
#Visualizing the private column
sns.countplot(instagram_df_train['private'],palette = "PuBu")
# Out:
# C:\Users\Ishwarya T\AppData\Local\Temp\ipykernel_12480\2746094449.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(instagram_df_train['private'],palette = "PuBu")
# <Axes: ylabel='count'>

# %%
#Visualizing the profile pic feature
sns.countplot(instagram_df_train['profile pic'],palette = "Pastel2")
# Out:
# C:\Users\Ishwarya T\AppData\Local\Temp\ipykernel_12480\2936145885.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(instagram_df_train['profile pic'],palette = "Pastel2")
# <Axes: ylabel='count'>

# %%
#Visualizing the length of usernames(Histogram)
plt.figure(figsize = (20, 10))
sns.distplot(instagram_df_train['nums/length username'],kde=True)
# Out:
# C:\Users\Ishwarya T\AppData\Local\Temp\ipykernel_12480\2810340997.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(instagram_df_train['nums/length username'],kde=True)
# <Axes: xlabel='nums/length username', ylabel='Density'>

# %%
#Correlation heatmap
plt.figure(figsize=(15,15))
cm = instagram_df_train.corr()
ax = plt.subplot()
sns.heatmap(cm, annot = True, ax = ax)
# Out:
# <Axes: >

# %%
sns.countplot(instagram_df_test['fake'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(instagram_df_test['private'],palette = "Set2")
# Out:
# C:\Users\Ishwarya T\AppData\Local\Temp\ipykernel_12480\1417521828.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(instagram_df_test['private'],palette = "Set2")
# <Axes: ylabel='count'>

# %%
sns.countplot(instagram_df_test['profile pic'])
# Out:
# <Axes: ylabel='count'>

# %%
x_test
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
#      name==username  description length  external URL  private  #posts  \
# 0                 1                  30             0        1      35
# 1                 0                  64             0        1       3
# 2                 0                  82             0        1     319
# 3                 0                 143             0        1     273
# 4                 0                  76             0        1       6
# ..              ...                 ...           ...      ...     ...
# 115               0                   0             0        0      13
# 116               0                   0             0        0       4
# 117               0                   0             0        0       3
# 118               0                   0             0        0       1
# 119               0                   0             0        0       3
#
#      #followers  #follows
# 0           488       604
# 1            35         6
# 2           328       668
# 3         14890      7369
# 4           225       356
# ..          ...       ...
# 115         114       811
# 116         150       164
# 117         833      3572
# 118         219      1695
# 119          39        68
#
# [120 rows x 11 columns]

# %%
#Preparing the outputs (Takin only the fake column into consideration.)
y_train = instagram_df_train['fake']
y_test = instagram_df_test['fake']
y_train
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 571    1
# 572    1
# 573    1
# 574    1
# 575    1
# Name: fake, Length: 576, dtype: int64

# %%
y_test
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 115    1
# 116    1
# 117    1
# 118    1
# 119    1
# Name: fake, Length: 120, dtype: int64

# %%
#Scaling the data before training the model (Normalize the data)
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X_train = scaler_x.fit_transform(x_train)
X_test = scaler_x.transform(x_test)

# %%
Y_train = tf.keras.utils.to_categorical(y_train, num_classes=2)
Y_test = tf.keras.utils.to_categorical(y_test, num_classes=2)

# %%
#Having a look at the shapes after scaling the data
X_train.shape,X_test.shape
# Out:
# ((576, 11), (120, 11))

# %%
Y_train.shape,Y_test.shape
# Out:
# ((576, 2), (120, 2))

# %%
#Percentage of Traininf data
Training_data_percentage = len(X_train)/(len(X_train) + len(X_test) ) * 100
Training_data_percentage
# Out:
# 82.75862068965517

# %%
Testing_data_percentage = len(X_test)/(len(X_train) + len(X_test) ) * 100
Testing_data_percentage
# Out:
# 17.24137931034483

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential() 
model.add(Dense(50,input_dim = 11, activation = "relu")) #Initial Layer
model.add(Dropout(0.3))
model.add(Dense(150, activation = "relu"))
model.add(Dropout(0.3))
model.add(Dense(25, activation = "relu"))
model.add(Dropout(0.3))
model.add(Dense(2, activation = "softmax")) #output layer

model.summary()
# Out:
# C:\Users\Ishwarya T\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 50)                  │             600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 150)                 │           7,650 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 150)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 25)                  │           3,775 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 25)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │              52 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,077 (47.18 KB)
#  Trainable params: 12,077 (47.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
epochs_hist = model.fit(X_train, Y_train, epochs = 20, verbose = 1, validation_split = 0.1)
# Out:
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5696 - loss: 0.6940 - val_accuracy: 0.8103 - val_loss: 0.5923
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8068 - loss: 0.5288 - val_accuracy: 0.8621 - val_loss: 0.3781
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8247 - loss: 0.4475 - val_accuracy: 0.8621 - val_loss: 0.2759
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8869 - loss: 0.3250 - val_accuracy: 0.8793 - val_loss: 0.2557
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8911 - loss: 0.3086 - val_accuracy: 0.8793 - val_loss: 0.2342
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9033 - loss: 0.2777 - val_accuracy: 0.8966 - val_loss: 0.2000
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9137 - loss: 0.2795 - val_accuracy: 0.8966 - val_loss: 0.1825
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9072 - loss: 0.2823 - val_accuracy: 0.8966 - val_loss: 0.1821
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8954 - loss: 0.2669 - val_accuracy: 0.8793 - val_loss: 0.2085
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9249 - loss: 0.2496 - val_accuracy: 0.8793 - val_loss: 0.1982
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9287 - loss: 0.2305 - val_accuracy: 0.8793 - val_loss: 0.2034
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9128 - loss: 0.2708 - val_accuracy: 0.8966 - val_loss: 0.1824
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9228 - loss: 0.2101 - val_accuracy: 0.8966 - val_loss: 0.1733
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9200 - loss: 0.2271 - val_accuracy: 0.8966 - val_loss: 0.1748
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8998 - loss: 0.2653 - val_accuracy: 0.8966 - val_loss: 0.1731
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9032 - loss: 0.2522 - val_accuracy: 0.8793 - val_loss: 0.1893
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8943 - loss: 0.2601 - val_accuracy: 0.8793 - val_loss: 0.1878
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9071 - loss: 0.2472 - val_accuracy: 0.8793 - val_loss: 0.1817
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9224 - loss: 0.2276 - val_accuracy: 0.8793 - val_loss: 0.2012
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9257 - loss: 0.2203 - val_accuracy: 0.8793 - val_loss: 0.1864

# %% [markdown]
# **<h2> TASK-7</h2>**
#
# ---
#
#
# **<h2><i>ASSESSING THE PRERFORMANCE OF THE MODEL**

# %% [markdown]
# ![confusion-matrix.png](data:image/png;base64,...)

# %%
print(epochs_hist.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progressioin During Training/Validation')
plt.xlabel('Epoch Number')
plt.ylabel('Training and Validation Losses')
plt.legend(['Training Loss','Valdiation Loss'])

# %%
predicted = model.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
predicted_value = []
test = []
for i in predicted:
    predicted_value.append(np.argmax(i))

for i in Y_test:
    test.append(np.argmax(i))

# %%
print(classification_report(test, predicted_value))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        60
#            1       0.91      0.85      0.88        60
#
#     accuracy                           0.88       120
#    macro avg       0.89      0.88      0.88       120
# weighted avg       0.89      0.88      0.88       120

# %%
plt.figure(figsize=(10, 10))
con_matrix = confusion_matrix(test,predicted_value)
sns.heatmap(con_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **<h2> INFERENCES AND CONCLUSION: </h2>**
#
# <i>
#
# * Thus, we have analyzed the dataset and obtained a fairly accurate predictive model using Neural networks.
#
# * The model is hence trained to detect fake accounts in instagram based on the considered features.
#
# * We achieved 95 percent accuracy in detecting the fake accounts by training the model using  datasets (from train.csv) . We have checked whether the model has reached the ability to detect an account is fake or not by inputting different set of data values (test.csv file) which consisted 120 account details.
#
# * The model predicted true values for 106 accounts and predicted false values for 14 accounts out of 120 accounts.

# %% [markdown]
# **<h2> REFERENCES : </h2>**
# Check out the following resources to learn more about the tools and libraries used in this notebook:
#
# <i>
#
#
# * Pandas user guide: https://pandas.pydata.org/docs/user_guide/index.html
#
# * Matplotlib user guide: https://matplotlib.org/3.3.1/users/index.html
#
# * Seaborn user guide & tutorial: https://seaborn.pydata.org/tutorial.html
#
# * Tensorflow user guide : https://www.tensorflow.org/guide
#
# * Tenorflow Playground : https://playground.tensorflow.org
#
# * Neural Networks : https://towardsdatascience.com/the-mostly-complete-chart-of-neural-networks-explained-3fb6f2367464

# %%
model.save("insta-fake-real.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model("insta-fake-real.h5")

# Assuming x_test and y_test are already available in your environment
# Make predictions (probabilities)
y_pred_prob = model.predict(x_test)

# Convert probabilities to binary class labels (0 or 1)
y_pred = (y_pred_prob > 0.5).astype("int").flatten()

# Convert y_test to a NumPy array if it's a Pandas Series
y_actual = y_test.to_numpy()

# Check the shape of actual and predicted values
print("Shape of y_actual:", y_actual.shape)
print("Shape of y_pred:", y_pred.shape)

# Ensure both have the same length (if needed)
min_len = min(len(y_actual), len(y_pred))
y_actual = y_actual[:min_len]
y_pred = y_pred[:min_len]

# Create a comparison DataFrame
df_comparison = pd.DataFrame({
    'Actual': y_actual,
    'Predicted': y_pred
})

# Show the first few rows of the comparison
print(df_comparison.sample(50))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Shape of y_actual: (120,)
# Shape of y_pred: (240,)
#      Actual  Predicted
# 78        1          1
# 33        0          0
# 73        1          0
# 79        1          0
# 77        1          0
# 93        1          0
# 97        1          0
# 63        1          0
# 14        0          1
# 22        0          1
# 37        0          0
# 12        0          1
# 98        1          1
# 116       1          1
# 2         0          1
# 66        1          1
# 70        1          1
# 28        0          1
# 1         0          0
# 38        0          1
# 103       1          0
# 29        0          0
# 54        0          1
# 109       1          0
# 11        0          0
# 56        0          1
# 80        1          1
# 39        0          0
# 17        0          0
# 71        1          0
# 52        0          1
# 75        1          0
# 84        1          1
# 53        0          0
# 30        0          1
# 8         0          1
# 50        0          1
# 117       1          0
# 49        0          0
# 67        1          0
# 118       1          1
# 112       1          1
# 111       1          0
# 91        1          0
# 7         0          0
# 104       1          1
# 24        0          1
# 65        1          0
# 25        0          0
# 76        1          1
